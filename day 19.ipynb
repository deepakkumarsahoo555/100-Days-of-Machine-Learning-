# %%
import pandas as pd

# %%
df =pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 1 . How big the data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## 2 . How does the data lool like ?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 262          263         0       1
# 358          359         1       3
# 21            22         1       2
# 555          556         0       1
# 251          252         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 262                           Taussig, Mr. Emil    male  52.0      1      1
# 358                        McGovern, Miss. Mary  female   NaN      0      0
# 21                        Beesley, Mr. Lawrence    male  34.0      0      0
# 555                          Wright, Mr. George    male  62.0      0      0
# 251  Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1      1
#
#      Ticket     Fare Cabin Embarked
# 262  110413  79.6500   E67        S
# 358  330931   7.8792   NaN        Q
# 21   248698  13.0000   D56        S
# 555  113807  26.5500   NaN        S
# 251  347054  10.4625    G6        S

# %% [markdown]
# ## 3. What is the data type of cols?

# %%
df .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 4.Are there any missing values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 5. How does the data look mathematically

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 6. Are there duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. How is the correlation between cols

# %%
# Option 1: Select only numerical columns before calculating correlation
# First, identify numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
# Then calculate correlation only on numerical columns
correlation_matrix = df[numerical_cols].corr()

# Option 2: If you need to include a specific text column after converting it
# For example, if you have categorical data that should be encoded:
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# df['encoded_column'] = le.fit_transform(df['text_column'])
# Then include this column in your correlation calculation
